# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')  # Suppressing warning

# %% [markdown]
# # Final Models Comparision

# %%
base_url = "https://raw.githubusercontent.com/Niyetali/FIFA-Rating-Prediction/main/output"

# importing dataset
models_summary = pd.read_csv(f"{base_url}/final.csv", sep=',')
models_summary.fillna('-', inplace=True)

models_summary
# Out:
#       Model     MSE      R2   Adj R2    RMSE     MAE    MAPE   SMAPE
# 0       OLS  4.4915  0.9297   0.9288  2.1193  1.6565  0.0270  0.0269
# 1  AdaBoost  0.8147  0.9872   0.9872  0.9025  0.4871  0.8231  0.8223
# 2   XGBoost  0.7905  0.9876   0.9876  0.8891  0.5525  0.9107  0.9111
# 3       MLP  1.7014  0.9733   0.9730  1.3043  0.9014  1.4755  1.4705

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" MSE"], color=['blue', 'orange', 'green', 'purple'])
plt.title("MSE Comparison Across Models")
plt.ylabel("MSE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" R2"], color=['blue', 'orange', 'green', 'purple'])
plt.title("R² Score Comparison Across Models")
plt.ylabel("R² Score")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" Adj R2"], color=['blue', 'orange', 'green', 'purple'])
plt.title("Adjusted R² Score Comparison Across Models")
plt.ylabel("Adjusted R² Score")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" RMSE"], color=['blue', 'orange', 'green', 'purple'])
plt.title("RMSE Comparison Across Models")
plt.ylabel("RMSE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" MAE"], color=['blue', 'orange', 'green', 'purple'])
plt.title("MAE Comparison Across Models")
plt.ylabel("MAE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" MAPE"], color=['blue', 'orange', 'green', 'purple'])
plt.title("MAPE Comparison Across Models")
plt.ylabel("MAPE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
plt.bar(models_summary["Model"], models_summary[" SMAPE"], color=['blue', 'orange', 'green', 'purple'])
plt.title("SMAPE Comparison Across Models")
plt.ylabel("SMAPE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Overview

# %% [markdown]
# The models exhibit strong predictive capabilities, with notable differences in performance metrics. OLS, serving as the baseline model without advanced ensemble techniques, achieves a respectable R² score of 0.9297 but struggles with higher error rates, reflected in an MSE of 4.4915 and an RMSE of 2.1193. Its MAE of 1.6565 further highlights its limitations in minimizing absolute errors.
#
# **AdaBoost**, after hyperparameter tuning, demonstrates a significant leap in accuracy. It achieves an impressive R² score of 0.9872, paired with a much lower MSE of 0.8147. Its standout feature is the lowest MAE of 0.4871 among all models, and its MAPE of 0.823% underscores its reliability in providing precise predictions.
#
# **XGBoost**, however, emerges as the top-performing model. With the highest R² score of 0.9876 and the smallest MSE of 0.7905, it outperforms the other models in overall accuracy. Its RMSE of 0.8891 indicates precise predictions, although its MAE of 0.5525 is slightly higher than that of AdaBoost. Nonetheless, the balance it achieves between precision and error minimization sets it apart.
#
# The **MLP model** offers satisfactory results, with an R² score of 0.9733 and an MSE of 1.7014. However, its higher RMSE of 1.3043 and MAE of 0.9014 suggest it lags behind the ensemble-based models, particularly in accuracy and error reduction.

# %% [markdown]
# # Additional Insights

# %% [markdown]
# Feature selection after hyperparameter tuning did not improve the results; however, the earlier steps of feature engineering and dataset refinement ensured that the models utilized the most relevant and impactful data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# *Hyperparameter tuning* proved to be a pivotal factor in enhancing model performance, with both AdaBoost and XGBoost making significant gains. ***XGBoost***, in particular, achieves the best overall results, making it the preferred choice for predicting FIFA 23 players ratings. Perhaps, the model would also show impressive results on future series of the football simulator, since the game does not change dramaticaly as proven through the years. Nevertheless, the model could be a pretty good instrument for real scouts or football analysts.
